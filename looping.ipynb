# %%
num = 10  # condition variableintialized with 10
while num < 15:
    print ("loop excutatingtime:",num-9)
    num =num + 1  # increament in the counter variable
# Out:
# loop excutatingtime: 1
# loop excutatingtime: 2
# loop excutatingtime: 3
# loop excutatingtime: 4
# loop excutatingtime: 5

# %%
counter = 0
while counter < 5:
    print ("loop count", counter + 1)
    counter = counter + 1
# Out:
# loop count 1
# loop count 2
# loop count 3
# loop count 4
# loop count 5

# %%
counter = 0
while counter < 5:
    print ("loop count", counter + 1)
    counter = counter - 1

# %%
# for
collection:
# [12,3,5,56,"class" ,"fruite"]
# (12,3,5,56,"class" ,"fruite")
# {"name:ali" ,age:15}
# {12,4,5,6,7}
# for variable in collection "we are learning loops "
# for variable in atm list

# %%
for data in[12,3,5,35]:
print(data)
# Out:
#   Cell In[9], line 2
#     print(data)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
for character in "we are learning python":
    print (character)
# Out:
# w
# e
#
# a
# r
# e
#
# l
# e
# a
# r
# n
# i
# n
# g
#
# p
# y
# t
# h
# o
# n

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
numbers = [1, 2, 3, 4, 5]
for num in numbers:
    if num % 2 == 0:
        continue
    print(num)
# Out:
# 1
# 3
# 5

# %%
list =(bags, shoes, dress,accessiores)
for list in list:
print ( list )
# Out:
#   Cell In[17], line 3
#     print ( list )
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
for i in range(1,11):
    print("5 x", i, "=", 5*i)
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
total = 0
for i in range(1,11):
    total = total + i

print("Sum =", total)
# Out:
# Sum = 55

# %%
numbers = [1,2,3,4,5]
total = 0

for i in numbers:
    total = total + i

print("Sum =", total)
# Out:
# Sum = 15
